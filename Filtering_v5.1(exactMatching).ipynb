# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import re

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 662 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if key_query['prdEnd'][:4] in nyear or key_query['prdStart'][:4] in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if (key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        A_id = [A_id]
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            # if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                            if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt) :  # 소속 같을때
#                                if site[i]
                                Answer_dict[tempName][site[i]]['A_id'].extend(A_id)
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            # if temp[key]['inst'] == all_inst[-1]  or (src != "" and src in tgt):  # 소속 같을때
                            if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
#print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가

# %%
import json
# Answer_dict = data0

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter, numInteErr
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
       
        if len(answer[name].keys()) > 1 :
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        else :
            pass
       #    print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name'].split('_')[0]
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            # if name+str(count) not in answer :
            #     print(name)
            while name+str(count) in answer :
                # if name+count in answer :
             #   print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

                
                #print("answer=",key, answer[key])
                '''
                if key not in Answer_dict :
                    count = 0
                    
                    while key+str(count) in Answer_dict :
                        # if name+count in answer :
                        print("result=", Answer_dict[ key+str(count)])                        
                        count += 1
                else :    
                    print("result=", Answer_dict[key])
                '''
            #print(key)|
            #print(answer[key])

    print("토탈앤써", answercount) 
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    
    print(keyid)    

#print(Answer_dict)
# Out:
# 171
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '아주대학교', 'SCIENCEON': 'East hall 206, Ajou University', 'KCI': '아주대학교 기계공학과'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '박태원', 'SCIENCEON': {'inst': '아주대학교 기계공학과', 'A_id': ['s290413'], 'papers': [ObjectId('61d54784de84cb5ab77cdf96')]}, 'KCI': {'inst': '아주대학교 기계공학과', 'A_id': ['s396986'], 'papers': [ObjectId('61d547870f91d3fd2b7cb839')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '아주대학교', 'SCIENCEON': 'East hall 206, Ajou University', 'KCI': '아주대학교 기계공학과'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '박태원', 'SCIENCEON': {'inst': '아주대학교 기계공학부', 'A_id': ['s275232'], 'papers': [ObjectId('61d54771de84cb5ab77cdf57')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '이경수', 'SCIENCEON': {'inst': '서울대학교 기계항공공학부 차량 동역학 및 제어 연구실', 'A_id': ['s298635'], 'papers': [ObjectId('61d54787de84cb5ab77cdf9d')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '이경수', 'SCIENCEON': {'inst': '서울대학교 차량동역학 및 제어연구실', 'A_id': ['s168877'], 'papers': [ObjectId('61d54784de84cb5ab77cdf98'), ObjectId('61d54787de84cb5ab77cdf9a')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '아주대학교', 'SCIENCEON': 'East hall 206, Ajou University', 'KCI': '아주대학교 기계공학과'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '박태원', 'SCIENCEON': {'inst': 'East hall 206, Ajou University', 'A_id': ['s307175', 's307175'], 'papers': [ObjectId('61d54781de84cb5ab77cdf90'), ObjectId('61d54781de84cb5ab77cdf90')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Mechatronics Engineering, Chungnam National University', 'KCI': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '김성수', 'SCIENCEON': {'inst': 'Dept. of Mechatronics Engineering, Chungnam National University', 'A_id': ['s314176'], 'papers': [ObjectId('61d5477fde84cb5ab77cdf80')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Mechatronics Engineering, Chungnam National University', 'KCI': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '김성수', 'SCIENCEON': {'inst': '충남대학교 메카트로닉스공학과', 'A_id': ['s196023'], 'papers': [ObjectId('61d54771de84cb5ab77cdf54'), ObjectId('61d54771de84cb5ab77cdf5c'), ObjectId('61d54778de84cb5ab77cdf76')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Mechatronics Engineering, Chungnam National University', 'KCI': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '김성수', 'SCIENCEON': {'inst': '충남대학교 메카트로닉스 공학과', 'A_id': ['s461337', 's461337'], 'papers': [ObjectId('61d5477fde84cb5ab77cdf83'), ObjectId('61d5477fde84cb5ab77cdf83')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '이경수', 'SCIENCEON': {'inst': '서울대학교 차량 동역학 및 제어 연구실', 'A_id': ['s555557', 's555557'], 'papers': [ObjectId('61d54789de84cb5ab77cdf9e'), ObjectId('61d54789de84cb5ab77cdf9e')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '아주대학
]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 미래자동차공학과', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '허건수', 'NTIS': {'inst': '한양대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyOTAwMDkwNTE5OQ=='], 'papers': [ObjectId('61d54777f8d08a558d7d11d7'), ObjectId('61d54777f8d08a558d7d11c4'), ObjectId('61d54775f8d08a558d7d1196'), ObjectId('61d54775f8d08a558d7d1192'), ObjectId('61d54779f8d08a558d7d11da')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 미래자동차공학과', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '허건수', 'SCIENCEON': {'inst': '한양대학교 미래자동차공학과', 'A_id': ['s325127'], 'papers': [ObjectId('61d54771de84cb5ab77cdf59')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '성균관대학교산학협력단', 'SCIENCEON': '성균관대학교 기계공학부'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '황성호', 'NTIS': {'inst': '성균관대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwNTE0MzgxNjg2Nw=='], 'papers': [ObjectId('61d54777f8d08a558d7d11d6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '성균관대학교산학협력단', 'SCIENCEON': '성균관대학교 기계공학부'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '황성호', 'SCIENCEON': {'inst': '성균관대학교 기계공학부', 'A_id': ['s66202'], 'papers': [ObjectId('61d54774de84cb5ab77cdf62')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울과학기술대학교', 'SCIENCEON': '서울과학기술대학교 철도차량시스템공학과', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '구정서', 'NTIS': {'inst': '서울과학기술대학교', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxMzU5ODYwNTE3OQ=='], 'papers': [ObjectId('61d5477bf8d08a558d7d1222'), ObjectId('61d5477bf8d08a558d7d1215'), ObjectId('61d54779f8d08a558d7d1200'), ObjectId('61d54779f8d08a558d7d11ef')]}, 'KCI': {'inst': '서울과학기술대학교', 'A_id': ['s101637'], 'papers': [ObjectId('61d5479a0f91d3fd2b7cb861'), ObjectId('61d5479a0f91d3fd2b7cb85e')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울과학기술대학교', 'SCIENCEON': '서울과학기술대학교 철도차량시스템공학과', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '구정서', 'SCIENCEON': {'inst': '서울과학기술대학교 철도차량시스템공학과', 'A_id': ['s570789'], 'papers': [ObjectId('61d54774de84cb5ab77cdf5f'), ObjectId('61d54774de84cb5ab77cdf67')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '충남대학교 기계설계공학과', 'KCI': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '강이석', 'KCI': {'inst': '충남대학교', 'A_id': ['s101809'], 'papers': [ObjectId('61d5478b0f91d3fd2b7cb841')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '충남대학교 기계설계공학과', 'KCI': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '강이석', 'SCIENCEON': {'inst': '충남대학교 기계설계공학과', 'A_id': ['s313164'], 'papers': [ObjectId('61d54778de84cb5ab77cdf77')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 미래자동차공학과', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '허건수', 'KCI': {'inst': '한양대학교', 'A_id': ['s101996', 's101996'], 'papers': [ObjectId('61d547910f91d3fd2b7cb84f'), ObjectId('61d547910f91d3fd2b7cb84f')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국철도기술연구원 고속철도연구팀', 'KCI': '한국철도기술연구원 고속철도연구팀'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '김석원', 'KCI': {'inst': '한국철도기술연구원', 'A_id': ['s102529'], 'papers': [ObjectId('61d547a50f91d3fd2b7cb873')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국교통대학교 철도차량시스템공학과', 'KCI': '한국교통대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '송문석', 'KCI': {'inst': '한국교통대학교', 'A_id': ['s102713'], 'papers': [ObjectId('61d547ae0f91d3fd2b7cb890')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국교통대학교 철도차량시스템공학과', 'KCI': '한국교통대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name':
]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국철도기술연구원 고속열차연구팀', 'KCI': '한국철도기술연구원'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '최성훈', 'KCI': {'inst': '한국철도기술연구원', 'A_id': ['s79936'], 'papers': [ObjectId('61d547ae0f91d3fd2b7cb887')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국철도기술연구원 고속열차연구팀', 'KCI': '한국철도기술연구원'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '최성훈', 'SCIENCEON': {'inst': '한국철도기술연구원 고속열차연구팀', 'A_id': ['s709117'], 'papers': [ObjectId('61d54781de84cb5ab77cdf8b')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국철도기술연구원 신교통연구본부', 'KCI': '한국철도기술연구원'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '강석원', 'KCI': {'inst': '한국철도기술연구원', 'A_id': ['s93958'], 'papers': [ObjectId('61d547ae0f91d3fd2b7cb889')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국철도기술연구원 신교통연구본부', 'KCI': '한국철도기술연구원'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '강석원', 'SCIENCEON': {'inst': '한국철도기술연구원 신교통연구본부', 'A_id': ['s457317'], 'papers': [ObjectId('61d54778de84cb5ab77cdf6f')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '부산대학교 기계공학부', 'KCI': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '유완석', 'KCI': {'inst': '부산대학교', 'A_id': ['s97869', 's97869'], 'papers': [ObjectId('61d547830f91d3fd2b7cb830'), ObjectId('61d547ae0f91d3fd2b7cb893'), ObjectId('61d547830f91d3fd2b7cb830'), ObjectId('61d547ae0f91d3fd2b7cb893')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국과학기술원 기계공학과', 'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '최세범', 'KCI': {'inst': '한국과학기술원', 'A_id': ['s98236'], 'papers': [ObjectId('61d547950f91d3fd2b7cb851')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국과학기술원 기계공학과', 'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 662, 'name': '최세범', 'SCIENCEON': {'inst': '한국과학기술원 기계공학과', 'A_id': ['s168880'], 'papers': [ObjectId('61d5477fde84cb5ab77cdf86')]}}
# num코렉트 133
# numEror 92
# numInteEror 89
# answer= 강석원 {'SCIENCEON': '한국철도기술연구원 신교통연구본부', 'KCI': '한국철도기술연구원'}
# answer= 강이석 {'SCIENCEON': '충남대학교 기계설계공학과', 'KCI': '충남대학교'}
# answer= 강주석 {'NTIS': '충주대학교 증평캠퍼스', 'KCI': '한국교통대학교'}
# answer= 구정서 {'NTIS': '서울과학기술대학교', 'SCIENCEON': '서울과학기술대학교 철도차량시스템공학과', 'KCI': '서울과학기술대학교'}
# answer= 김광석 {'SCIENCEON': '인하공업전문대학 자동차과', 'KCI': '인하공업전문대학'}
# answer= 김기운 {'SCIENCEON': '금호타이어 중앙연구소', 'KCI': '금호타이어'}
# answer= 김성수 {'SCIENCEON': 'Department of Mechatronics Engineering, Chungnam National University', 'KCI': '충남대학교'}
# answer= 김영철 {'SCIENCEON': 'Dept. of Electronics Eng., Chungbuk National University', 'KCI': '충북대학교'}
# answer= 김정태 {'SCIENCEON': 'Department of Mechanical System Design Engineering, Hongik University', 'KCI': '홍익대학교'}
# answer= 김형우 {'SCIENCEON': '한국해양과학기술원 부설 선박해양플랜트연구소 해양플랜트산업기술센터', 'KCI': '한국해양과학기술원'}
# answer= 김희철 {'SCIENCEON': '광주대학교 컴퓨터공학과', 'KCI': '광주대학교'}
# answer= 박신석 {'SCIENCEON': 'Mechanical Engineering, Korea University', 'KCI': '고려대학교'}
# answer= 박재용 {'SCIENCEON': '현대자동차 연구개발본부', 'KCI': '현대자동차'}
# answer= 박정수 {'SCIENCEON': '국방과학연구소 제1기술연구본부', 'KCI': '국방과학연구소'}
# answer= 박태원 {'NTIS': '아주대학교', 'SCIENCEON': 'East hall 206, Ajou University', 'KCI': '아주대학교 기계공학과'}
# answer= 송문석 {'SCIENCEON': '한국교통대학교 철도차량시스템공학과', 'KCI': '한국교통대학교'}
# answer= 양석조 {'SCIENCEON': '충남대학교 메카트로닉스공학과', 'KCI': '충남대학교'}
# answer= 양인범 {'SCIENCEON': '순천향대학교 스마트자동차학과', 'KCI': '순천향대학교'}
# answer= 오상훈 {'SCIENCEON': '국방과학연구소 제1기술연구본부', 'KCI': '국방과학연구소 연구원'}
# answer= 오현석 {'SCIENCEON': '서울과학기술대학교 철도차량시스템공학과', 'KCI': '서울과학기술대학교'}
# answer= 유승한 {'NTIS': '한국기술교육대학교', 'SCIENCEON': '한국기술교육대학교 기계공학부', 'KCI': '한국기술교육대학교'}
# answer= 유완석0 {'SCIENCEON': '부산대학교 기계공학부', 'KCI': '부산대학교'}
# answer= 이경수 {'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
# answer= 이광수 {'SCIENCEON': '자동차부품연구원 자율주행기술연구센터', 'KCI': '자동차부품연구원'}
# answer= 이종민 {'SCIENCEON': 'Department of Levitation and Linear Drive, KIMM(Korea Institude Machinery and Materials)', 'KCI': '한국기계연구원'}
# answer= 이지홍 {'SCIENCEON': '충남대학교 메카트로닉스 공학과', 'KCI': '충남대학교'}
# answer= 이진희 {'SCIENCEON': '아주대학교 기계공학부', 'KCI': '아주대학교'}
# answer= 이형철 {'SCIENCEON': '한양대학교 전기생체공학부', 'KCI': '한양대학교', 'NTIS': '한양대학교산학협력단'}
# answer= 장명언 {'SCIENCEON': '국방과학연구소 제5기술연구본부', 'KCI': '국방과학연구소'}
# answer= 정기범 {'SCIENCEON': 'Graduate School of Mechanical Engineering, Ajou University', 'KCI': '아주대학교'}
# answer= 조병관 {'SCIENCEON': '한국기술교육대학교 기계공학부', 'KCI': '한국기술교육대학교'}
# answer= 주상현 {'SCIENCEON': '국방과학연구소 제5기술연구본부', 'KCI': '국방과학연구소'}
# answer= 최성훈 {'SCIENCEON': '한국철도기술연구원 고속열차연구팀', 'KCI': '한국철도기술연구원'}
# answer= 최세범 {'SCIENCEON': '한국과학기술원 기계공학과', 'KCI': '한국과학기술원'}
# answer= 최재웅 {'SCIENCEON': '서울대학교 기계공학부', 'KCI': '서울대학교'}
# answer= 하정호 {'SCIENCEON': '한국기술교육대학교 기계정보공학부', 'KCI': '한국기술교육대학교'}
# answer= 허건수 {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 미래자동차공학과', 'KCI': '한양대학교'}
# answer= 황성호 {'NTIS': '성균관대학교산학협력단', 'SCIENCEON': '성균관대학교 기계공학부'}
# 토탈앤써 171
# 토탈인터그레이션 48
# --------------------------------
# 토탈에러 38
# 토탈인터그레이션에러 38
# 662

# %%
a = jaro.jaro_winkler_metric('성균관대학교', '성균관대학교(자연과학캠퍼스)')
print(a)
# Out:
# 0.88

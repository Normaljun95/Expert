# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import re

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 663 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if key_query['prdEnd'][:4] in nyear or key_query['prdStart'][:4] in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if (key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        A_id = [A_id]
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            # if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                            if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt) :  # 소속 같을때
#                                if site[i]
                                Answer_dict[tempName][site[i]]['A_id'].extend(A_id)
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            # if temp[key]['inst'] == all_inst[-1]  or (src != "" and src in tgt):  # 소속 같을때
                            if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
#print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가

# %%
import json
# Answer_dict = data0

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter, numInteErr
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
       
        if len(answer[name].keys()) > 1 :
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        else :
            pass
       #    print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name'].split('_')[0]
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            # if name+str(count) not in answer :
            #     print(name)
            while name+str(count) in answer :
                # if name+count in answer :
             #   print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

                
                #print("answer=",key, answer[key])
                '''
                if key not in Answer_dict :
                    count = 0
                    
                    while key+str(count) in Answer_dict :
                        # if name+count in answer :
                        print("result=", Answer_dict[ key+str(count)])                        
                        count += 1
                else :    
                    print("result=", Answer_dict[key])
                '''
            #print(key)|
            #print(answer[key])

    print("토탈앤써", answercount) 
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    
    print(keyid)    

#print(Answer_dict)
# Out:
# 212
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '경남과학기술대학교', 'KCI': '경남과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '박진현', 'SCIENCEON': {'inst': 'Dept. of Mechatronics Engineering, Gyeognam Nat. Univ. of Science and Technology', 'A_id': ['s1347376'], 'papers': [ObjectId('61d54a90de84cb5ab77cdfea')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울대학교', 'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '이경수', 'SCIENCEON': {'inst': '서울대학교 기계항공공학부', 'A_id': ['s83526'], 'papers': [ObjectId('61d54a83de84cb5ab77cdfc3'), ObjectId('61d54a88de84cb5ab77cdfd6'), ObjectId('61d54a90de84cb5ab77cdfe7'), ObjectId('61d54a94de84cb5ab77cdfec')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울대학교', 'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '이경수', 'SCIENCEON': {'inst': 'School of Mechanical and Aerospace Engineering, Seoul National University', 'A_id': ['s1420023'], 'papers': [ObjectId('61d54a7cde84cb5ab77cdfac')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '아주대학교산학협력단', 'SCIENCEON': '아주대학교 기계공학과'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '송봉섭', 'NTIS': {'inst': '아주대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjEyNDY0MDEwNzExNw=='], 'papers': [ObjectId('61d54a82f8d08a558d7d12b9'), ObjectId('61d54a80f8d08a558d7d12ae'), ObjectId('61d54a7ef8d08a558d7d126f'), ObjectId('61d54a7af8d08a558d7d122c')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '아주대학교산학협력단', 'SCIENCEON': '아주대학교 기계공학과'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '송봉섭', 'SCIENCEON': {'inst': '아주대학교 기계공학과', 'A_id': ['s297231'], 'papers': [ObjectId('61d54a80de84cb5ab77cdfb6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교 에리카 산학협력단', 'SCIENCEON': '한양대학교 기계공학과'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '한창수', 'NTIS': {'inst': '한양대학교 에리카 산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxMTMwODU2NTE1Mw==', 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYwMjEzNDQyNjI3MQ=='], 'papers': [ObjectId('61d54a87f8d08a558d7d1312'), ObjectId('61d54a87f8d08a558d7d1307')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교 에리카 산학협력단', 'SCIENCEON': '한양대학교 기계공학과'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '한창수', 'SCIENCEON': {'inst': '한양대학교 기계공학과', 'A_id': ['s432238'], 'papers': [ObjectId('61d54a7cde84cb5ab77cdfb0')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 전기생체공학부', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '정정주', 'NTIS': {'inst': '한양대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyNTYxOTk0NTE4NA=='], 'papers': [ObjectId('61d54a8af8d08a558d7d1333'), ObjectId('61d54a89f8d08a558d7d1326'), ObjectId('61d54a87f8d08a558d7d1319'), ObjectId('61d54a87f8d08a558d7d1305'), ObjectId('61d54a84f8d08a558d7d12f6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 전기생체공학부', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '정정주', 'SCIENCEON': {'inst': '한양대학교 전기생체공학부', 'A_id': ['s276030'], 'papers': [ObjectId('61d54a83de84cb5ab77cdfbd')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한국과학기술원', 'SCIENCEON': '한국과학기술원 건설 및 환경공학과', 'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '여화수', 'NTIS': {'inst': '한국과학기술원', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjMxMTEwNDI3NzEyMg=='], 'papers': [ObjectId('61d54a84f8d08a558d7d12f9')]}, 'KCI': {'inst': '한국과학기술원', 'A_id': ['s11386'], 'papers': [ObjectId('61d54a930f91d3fd2b7cb902')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한국과학기술원', 'SCIENCEON': '한국과학기술원 건설 및 환경공학과', 'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '여화수', 'SCIENCEON': {'inst': '한국과학기술원 건설 및 환경공학과', 'A_id': ['s297856'], 'papers': [ObjectId('61d54a86de84cb5ab77cdfd1')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '성균관대학교산학협력단', 'SCIENCEON': 'Department of Mechanical Engineering, Sungkyunkwan University', 'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '황성호', 'NTIS': {'inst': '성균관대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwNTE0MzgxNjg2Nw=='], 'papers': [ObjectId('61d54a87f8d08a558d7d1306'), ObjectId('61d54a84f8d08a558d7d12f8')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '성균관대학교산학협력단', 'SCIENCEON': 'Department of Mechanical Engineering, Sungkyunkwan University', 'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '황성호', 'SCIENCEON': {'inst': 'Department of Mechanical Engineering, Sungkyunkwan University', 'A_id': ['s297515'], 'papers': [ObjectId('61d54a83de84cb5ab77cdfc0')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울대학교', 'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '이경수', 'NTIS': {'inst': '서울대학교', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwMjExNTIyNjE2Nw==', 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwMjExNTIyNjE2Nw=='], 'papers': [ObjectId('61d54a8af8d08a558d7d1339'), ObjectId('61d54a87f8d08a558d7d130f'), ObjectId('61d54a84f8d08a558d7d12db'), ObjectId('61d54a82f8d08a558d7d12b2'), ObjectId('61d54a7ef8d08a558d7d127a'), ObjectId('61d54a7cf8d08a558d7d1257'), ObjectId('61d54a8af8d08a558d7d1339'), ObjectId('61d54a87f8d08a558d7d130f'), ObjectId('61d54a84f8d08a558d7d12db'), ObjectId('61d54a82f8d08a558d7d12b2'), ObjectId('61d54a7ef8d08a558d7d127a'), ObjectId('61d54a7cf8d08a558d7d1257')]}, 'KCI': {'inst': '서울대학교', 'A_id': ['s5936'], 'papers': [ObjectId('61d54a870f91d3fd2b7cb8d1'), ObjectId('61d54a870f91d3fd2b7cb8cf'), ObjectId('61d54a870f91d3fd2b7cb8c7')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '국립목포대학교 산학협력단', 'SCIENCEON': '목포대학교 제어로봇공학과'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '유영재', 'NTIS': {'inst': '국립목포대학교 산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjY2ODE2MjkyNjE0MA=='], 'papers': [ObjectId('61d54a89f8d08a558d7d131d'), ObjectId('61d54a87f8d08a558d7d1309'), ObjectId('61d54a84f8d08a558d7d12f1'), ObjectId('61d54a89f8d08a558d7d1320')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '국립목포대학교 산학협력단', 'SCIENCEON': '목포대학교 제어로봇공학과'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '유영재', 'SCIENCEON': {'inst': '목포대학교 제어로봇공학과', 'A_id': ['s62143'], 'papers': [ObjectId('61d54a78de84cb5ab77cdfa6'), ObjectId('61d54a86de84cb5ab77cdfd0')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울대학교산학협력단', 'SCIENCEON': '서울대학교 바이오시스템 소재학부'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김학진', 'NTIS': {'inst': '서울대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwOTE0NDcyNjkyNw=='], 'papers': [ObjectId('61d54a84f8d08a558d7d12f4'), ObjectId('61d54a80f8d08a558d7d12a9'), ObjectId('61d54a80f8d08a558d7d12a5'), ObjectId('61d54a7ef8d08a558d7d1284')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울대학교산학협력단', 'SCIENCEON': '서울대학교 바이오시스템 소재학부'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김학진', 'SCIENCEON': {'inst': '서울대학교 바이오시스템 소재학부', 'A_id': ['s61836'], 'papers': [ObjectId('61d54a88de84cb5ab77cdfdc')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '허건수', 'KCI': {'inst': '한양대학교', 'A_id': ['s101996'], 'papers': [ObjectId('61d54a870f91d3fd2b7cb8c6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '허건수', 'NTIS': {'inst': '한양대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyOTAwMDkwNTE5OQ=='], 'papers': [ObjectId('61d54a87f8d08a558d7d1318'), ObjectId('61d54a84f8d08a558d7d12f5'), ObjectId('61d54a82f8d08a558d7d12ba')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '현대로템(주) 기술연구소', 'KCI': '현대로템 기술연구소'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '우관제', 'KCI': {'inst': '현대로템 기술연구소', 'A_id': ['s105405'], 'papers': [ObjectId('61d54a870f91d3fd2b7cb8c8')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '현대로템(주) 기술연구소', 'KCI': '현대로템 기술연구소'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '우관제', 'SCIENCEON': {'inst': '현대로템(주) 기술연구소', 'A_id': ['s1420020'], 'papers': [ObjectId('61d54a78de84cb5ab77cdfa5')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '국방과학연구소 제5기술연구본부', 'KCI': '국방과학연구소'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '주상현', 'KCI': {'inst': '국방과학연구소', 'A_id': ['s108522'], 'papers': [ObjectId('61d54a870f91d3fd2b7cb8c3')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '국방과학연구소 제5기술연구본부', 'KCI': '국방과학연구소'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '주상현', 'SCIENCEON': {'inst': '국방과학연구소 제5기술연구본부', 'A_id': ['s297991'], 'papers': [ObjectId('61d54a88de84cb5ab77cdfd5')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '전북대학교 기계시스템공학부', 'KCI': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '양성모', 'KCI': {'inst': '전북대학교', 'A_id': ['s110693'], 'papers': [ObjectId('61d54a8e0f91d3fd2b7cb8e7')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '전북대학교 기계시스템공학부', 'KCI': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '양성모', 'SCIENCEON': {'inst': '전북대학교 기계시스템공학부', 'A_id': ['s570825'], 'papers': [ObjectId('61d54a80de84cb5ab77cdfbb')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국건설기술연구원 도로연구소', 'KCI': '한국건설기술연구원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김형수', 'KCI': {'inst': '한국건설기술연구원', 'A_id': ['s118952'], 'papers': [ObjectId('61d54a8f0f91d3fd2b7cb8f3')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국건설기술연구원 도로연구소', 'KCI': '한국건설기술연구원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김형수', 'SCIENCEON': {'inst': '한국건설기술연구원 도로연구소', 'A_id': ['s297639'], 'papers': [ObjectId('61d54a86de84cb5ab77cdfc9')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '연세대학교 전기전자공학부', 'KCI': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '윤영중', 'KCI': {'inst': '연세대학교', 'A_id': ['s119581'], 'papers': [ObjectId('61d54a8e0f91d3fd2b7cb8e9')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '연세대학교 전기전자공학부', 'KCI': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '윤영중', 'SCIENCEON': {'inst': '연세대학교 전기전자공학부', 'A_id': ['s1056338'], 'papers': [ObjectId('61d54a88de84cb5ab77cdfd8')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Agency for Defense Development', 'KCI': '국방과학연구소(대전)'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '허기봉', 'KCI': {'inst': '국방과학연구소(대전)', 'A_id': ['s124856'], 'papers': [ObjectId('61d54a930f91d3fd2b7cb8f6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Agency for Defense Development', 'KCI': '국방과학연구소(대전)'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '허기봉', 'SCIENCEON': {'inst': 'Agency for Defense Development', 'A_id': ['s307704'], 'papers': [ObjectId('61d54a80de84cb5ab77cdfba')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '호서대학교 전기공학과', 'KCI': '호서대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '송영은', 'KCI': {'inst': '호서대학교', 'A_id': ['s13303'], 'papers': [ObjectId('61d54a940f91d3fd2b7cb905')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '호서대학교 전기공학과', 'KCI': '호서대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '송영은', 'SCIENCEON': {'inst': '호서대학교 전기공학과', 'A_id': ['s748221'], 'papers': [ObjectId('61d54a90de84cb5ab77cdfe9')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '아주대학교 기계공학과', 'KCI': '아주대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '박태원', 'KCI': {'inst': '아주대학교', 'A_id': ['s20'], 'papers': [ObjectId('61d54a840f91d3fd2b7cb8bd')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '아주대학교 기계공학과', 'KCI': '아주대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '박태원', 'SCIENCEON': {'inst': '아주대학교 기계공학과', 'A_id': ['s290413'], 'papers': [ObjectId('61d54a80de84cb5ab77cdfb4')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국생산기술연구원 융합생산기술연구소 휴먼문화융합그룹', 'KCI': '한국생산기술연구원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '이설희', 'KCI': {'inst': '한국생산기술연구원', 'A_id': ['s273835'], 'papers': [ObjectId('61d54a940f91d3fd2b7cb904')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국생산기술연구원 융합생산기술연구소 휴먼문화융합그룹', 'KCI': '한국생산기술연구원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '이설희', 'SCIENCEON': {'inst': '한국생산기술연구원 융합생산기술연구소 휴먼문화융합그룹', 'A_id': ['s1420037'], 'papers': [ObjectId('61d54a83de84cb5ab77cdfbf')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국해양대학교 기관공학과', 'KCI': '한국해양대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '오진석', 'KCI': {'inst': '한국해양대학교', 'A_id': ['s29093'], 'papers': [ObjectId('61d54a890f91d3fd2b7cb8dd')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국해양대학교 기관공학과', 'KCI': '한국해양대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '오진석', 'SCIENCEON': {'inst': '한국해양대학교 기관공학과', 'A_id': ['s261350'], 'papers': [ObjectId('61d54a7cde84cb5ab77cdfae')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Naval System R&D Center, Hanwha Systems', 'KCI': '한화시스템'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최병웅', 'KCI': {'inst': '한화시스템', 'A_id': ['s304107'], 'papers': [ObjectId('61d54a930f91d3fd2b7cb8fd')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Naval System R&D Center, Hanwha Systems', 'KCI': '한화시스템'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최병웅', 'SCIENCEON': {'inst': 'Naval System R&D Center, Hanwha Systems', 'A_id': ['s694123'], 'papers': [ObjectId('61d54a88de84cb5ab77cdfdb')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '목원대학교 지능로봇공학과', 'KCI': '목원대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '양태규', 'KCI': {'inst': '목원대학교', 'A_id': ['s305695'], 'papers': [ObjectId('61d54a830f91d3fd2b7cb8a6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '목원대학교 지능로봇공학과', 'KCI': '목원대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '양태규', 'SCIENCEON': {'inst': '목원대학교 지능로봇공학과', 'A_id': ['s653514'], 'papers': [ObjectId('61d54a86de84cb5ab77cdfcd')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울과학기술대학교 기계.자동차공학과', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김우일', 'KCI': {'inst': '서울과학기술대학교', 'A_id': ['s357707'], 'papers': [ObjectId('61d54a890f91d3fd2b7cb8df')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울과학기술대학교 기계.자동차공학과', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김우일', 'SCIENCEON': {'inst': '서울과학기술대학교 기계.자동차공학과', 'A_id': ['s1420043'], 'papers': [ObjectId('61d54a86de84cb5ab77cdfcf')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울과학기술대학교 산업대학원 자동차공학과', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '조성익', 'KCI': {'inst': '서울과학기술대학교', 'A_id': ['s357709'], 'papers': [ObjectId('61d54a8c0f91d3fd2b7cb8e1')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울과학기술대학교 산업대학원 자동차공학과', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '조성익', 'SCIENCEON': {'inst': '서울과학기술대학교 산업대학원 자동차공학과', 'A_id': ['s1003282'], 'papers': [ObjectId('61d54a83de84cb5ab77cdfc6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '군산대학교 해양산업운송과학기술학부', 'KCI': '군산대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '정초영', 'KCI': {'inst': '군산대학교', 'A_id': ['s387953'], 'papers': [ObjectId('61d54a970f91d3fd2b7cb909')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '군산대학교 해양산업운송과학기술학부', 'KCI': '군산대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '정초영', 'SCIENCEON': {'inst': '군산대학교 해양산업운송과학기술학부', 'A_id': ['s1420048'], 'papers': [ObjectId('61d54a88de84cb5ab77cdfd7')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '동명대학교 전자공학과', 'KCI': '동명대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '손영선', 'KCI': {'inst': '동명대학교', 'A_id': ['s545452'], 'papers': [ObjectId('61d54a890f91d3fd2b7cb8da')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '동명대학교 전자공학과', 'KCI': '동명대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '손영선', 'SCIENCEON': {'inst': '동명대학교 전자공학과', 'A_id': ['s1420031'], 'papers': [ObjectId('61d54a80de84cb5ab77cdfb8')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Communication-CW Team, Hanwha Systems', 'KCI': '한화시스템(주)'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '유병길', 'KCI': {'inst': '한화시스템(주)', 'A_id': ['s545463'], 'papers': [ObjectId('61d54a8f0f91d3fd2b7cb8ed')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Communication-CW Team, Hanwha Systems', 'KCI': '한화시스템(주)'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '유병길', 'SCIENCEON': {'inst': 'Communication-CW Team, Hanwha Systems', 'A_id': ['s1420054'], 'papers': [ObjectId('61d54a9bde84cb5ab77cdfef')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '광운대학교 전자공학과', 'KCI': '광운대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김정근', 'KCI': {'inst': '광운대학교', 'A_id': ['s545468'], 'papers': [ObjectId('61d54a940f91d3fd2b7cb903')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '광운대학교 전자공학과', 'KCI': '광운대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '김정근', 'SCIENCEON': {'inst': '광운대학교 전자공학과', 'A_id': ['s1056354'], 'papers': [ObjectId('61d54a88de84cb5ab77cdfd9')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '부경대학교 환경해양대학 에너지자원공학과', 'KCI': '부경대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최요순', 'KCI': {'inst': '부경대학교', 'A_id': ['s56721'], 'papers': [ObjectId('61d54a930f91d3fd2b7cb8fc'), ObjectId('61d54a930f91d3fd2b7cb8fe')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '부경대학교 환경해양대학 에너지자원공학과', 'KCI': '부경대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최요순', 'SCIENCEON': {'inst': '부경대학교 환경해양대학 에너지자원공학과', 'A_id': ['s266651'], 'papers': [ObjectId('61d54a90de84cb5ab77cdfeb')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '남서울대학교 전자공학과', 'KCI': '남서울대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '고윤석', 'KCI': {'inst': '남서울대학교', 'A_id': ['s6581'], 'papers': [ObjectId('61d54a8f0f91d3fd2b7cb8ec'), ObjectId('61d54a870f91d3fd2b7cb8cd')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '남서울대학교 전자공학과', 'KCI': '남서울대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '고윤석', 'SCIENCEON': {'inst': '남서울대학교 전자공학과', 'A_id': ['s136298'], 'papers': [ObjectId('61d54a94de84cb5ab77cdfee'), ObjectId('61d54a94de84cb5ab77cdfed')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '호남대학교', 'KCI': '호남대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '오광석', 'KCI': {'inst': '한경대학교', 'A_id': ['s70382'], 'papers': [ObjectId('61d54a830f91d3fd2b7cb8b2'), ObjectId('61d54a870f91d3fd2b7cb8c2')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '부산대학교 산학협력단', 'KCI': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '안창선', 'KCI': {'inst': '부산대학교', 'A_id': ['s71393'], 'papers': [ObjectId('61d54a830f91d3fd2b7cb8a5')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '부산대학교 산학협력단', 'KCI': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '안창선', 'NTIS': {'inst': '부산대학교 산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxMDg2MjEyNzE3Mw=='], 'papers': [ObjectId('61d54a82f8d08a558d7d12bb'), ObjectId('61d54a80f8d08a558d7d12ac'), ObjectId('61d54a87f8d08a558d7d1310'), ObjectId('61d54a84f8d08a558d7d12e9')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '아주대학교 정보컴퓨터공학부', 'KCI': '아주대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최경희', 'KCI': {'inst': '아주대학교', 'A_id': ['s79803'], 'papers': [ObjectId('61d54a830f91d3fd2b7cb8a9')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '아주대학교 정보컴퓨터공학부', 'KCI': '아주대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최경희', 'SCIENCEON': {'inst': '아주대학교 정보컴퓨터공학부', 'A_id': ['s1032019'], 'papers': [ObjectId('61d54a7cde84cb5ab77cdfab')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '계명대학교 기계자동차공학과', 'KCI': '계명대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '이선봉', 'KCI': {'inst': '계명대학교', 'A_id': ['s829'], 'papers': [ObjectId('61d54a930f91d3fd2b7cb8ff'), ObjectId('61d54a8f0f91d3fd2b7cb8ee')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '계명대학교 기계자동차공학과', 'KCI': '계명대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '이선봉', 'SCIENCEON': {'inst': '계명대학교 기계자동차공학과', 'A_id': ['s61868'], 'papers': [ObjectId('61d54a86de84cb5ab77cdfca'), ObjectId('61d54a90de84cb5ab77cdfe8')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Automotive Components Research Group, Honam Regional Division, Korea Institute of Industrial Technology', 'KCI': '한국생산기술연구원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '차현록', 'KCI': {'inst': '한국생산기술연구원', 'A_id': ['s84160'], 'papers': [ObjectId('61d54a970f91d3fd2b7cb90a')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Automotive Components Research Group, Honam Regional Division, Korea Institute of Industrial Technology', 'KCI': '한국생산기술연구원'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '차현록', 'SCIENCEON': {'inst': 'Automotive Components Research Group, Honam Regional Division, Korea Institute of Industrial Technology', 'A_id': ['s1048457'], 'papers': [ObjectId('61d54a83de84cb5ab77cdfbc')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Bio-Mechatronic Engineering, Sungkyunkwan University', 'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최창현', 'KCI': {'inst': '성균관대학교', 'A_id': ['s85926'], 'papers': [ObjectId('61d54a830f91d3fd2b7cb8b4')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Bio-Mechatronic Engineering, Sungkyunkwan University', 'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '최창현', 'SCIENCEON': {'inst': 'Department of Bio-Mechatronic Engineering, Sungkyunkwan University', 'A_id': ['s1420042'], 'papers': [ObjectId('61d54a86de84cb5ab77cdfcc')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 전기생체공학부', 'KCI': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '정정주', 'KCI': {'inst': '한양대학교', 'A_id': ['s88447', 's88447'], 'papers': [ObjectId('61d54a890f91d3fd2b7cb8d3'), ObjectId('61d54a890f91d3fd2b7cb8d3')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Biosystems Machinery Engineering, Chungnam National University', 'KCI': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '서자호', 'KCI': {'inst': '충남대학교', 'A_id': ['s88534'], 'papers': [ObjectId('61d54a870f91d3fd2b7cb8c9'), ObjectId('61d54a870f91d3fd2b7cb8ce')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Biosystems Machinery Engineering, Chungnam National University', 'KCI': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '서자호', 'SCIENCEON': {'inst': 'Department of Biosystems Machinery Engineering, Chungnam National University', 'A_id': ['s325736'], 'papers': [ObjectId('61d54a88de84cb5ab77cdfda'), ObjectId('61d54a88de84cb5ab77cdfd3')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '성균관대학교산학협력단', 'SCIENCEON': 'Department of Mechanical Engineering, Sungkyunkwan University', 'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 663, 'name': '황성호', 'KCI': {'inst': '성균관대학교', 'A_id': ['s94648', 's94648'], 'papers': [ObjectId('61d54a830f91d3fd2b7cb8a4'), ObjectId('61d54a830f91d3fd2b7cb8a4')]}}
# num코렉트 177
# numEror 79
# numInteEror 75
# answer= 고윤석 {'SCIENCEON': '남서울대학교 전자공학과', 'KCI': '남서울대학교'}
# answer= 김우일 {'SCIENCEON': '서울과학기술대학교 기계.자동차공학과', 'KCI': '서울과학기술대학교'}
# answer= 김정근 {'SCIENCEON': '광운대학교 전자공학과', 'KCI': '광운대학교'}
# answer= 김학진 {'NTIS': '서울대학교산학협력단', 'SCIENCEON': '서울대학교 바이오시스템 소재학부'}
# answer= 김형수 {'SCIENCEON': '한국건설기술연구원 도로연구소', 'KCI': '한국건설기술연구원'}
# answer= 박태원 {'SCIENCEON': '아주대학교 기계공학과', 'KCI': '아주대학교'}
# answer= 서자호 {'SCIENCEON': 'Department of Biosystems Machinery Engineering, Chungnam National University', 'KCI': '충남대학교'}
# answer= 손영선 {'SCIENCEON': '동명대학교 전자공학과', 'KCI': '동명대학교'}
# answer= 송봉섭 {'NTIS': '아주대학교산학협력단', 'SCIENCEON': '아주대학교 기계공학과'}
# answer= 송영은 {'SCIENCEON': '호서대학교 전기공학과', 'KCI': '호서대학교'}
# answer= 안창선 {'NTIS': '부산대학교 산학협력단', 'KCI': '부산대학교'}
# answer= 양성모 {'SCIENCEON': '전북대학교 기계시스템공학부', 'KCI': '전북대학교'}
# answer= 양태규 {'SCIENCEON': '목원대학교 지능로봇공학과', 'KCI': '목원대학교'}
# answer= 여화수 {'NTIS': '한국과학기술원', 'SCIENCEON': '한국과학기술원 건설 및 환경공학과', 'KCI': '한국과학기술원'}
# answer= 오진석 {'SCIENCEON': '한국해양대학교 기관공학과', 'KCI': '한국해양대학교'}
# answer= 우관제 {'SCIENCEON': '현대로템(주) 기술연구소', 'KCI': '현대로템 기술연구소'}
# answer= 유병길 {'SCIENCEON': 'Communication-CW Team, Hanwha Systems', 'KCI': '한화시스템(주)'}
# answer= 유영재 {'NTIS': '국립목포대학교 산학협력단', 'SCIENCEON': '목포대학교 제어로봇공학과'}
# answer= 윤영중 {'SCIENCEON': '연세대학교 전기전자공학부', 'KCI': '연세대학교'}
# answer= 이경수 {'NTIS': '서울대학교', 'SCIENCEON': '서울대학교 기계항공공학부', 'KCI': '서울대학교'}
# answer= 이선봉 {'SCIENCEON': '계명대학교 기계자동차공학과', 'KCI': '계명대학교'}
# answer= 이설희 {'SCIENCEON': '한국생산기술연구원 융합생산기술연구소 휴먼문화융합그룹', 'KCI': '한국생산기술연구원'}
# answer= 정정주 {'NTIS': '한양대학교산학협력단', 'SCIENCEON': '한양대학교 전기생체공학부', 'KCI': '한양대학교'}
# answer= 정초영 {'SCIENCEON': '군산대학교 해양산업운송과학기술학부', 'KCI': '군산대학교'}
# answer= 조성익 {'SCIENCEON': '서울과학기술대학교 산업대학원 자동차공학과', 'KCI': '서울과학기술대학교'}
# answer= 주상현 {'SCIENCEON': '국방과학연구소 제5기술연구본부', 'KCI': '국방과학연구소'}
# answer= 차현록 {'SCIENCEON': 'Automotive Components Research Group, Honam Regional Division, Korea Institute of Industrial Technology', 'KCI': '한국생산기술연구원'}
# answer= 최경희 {'SCIENCEON': '아주대학교 정보컴퓨터공학부', 'KCI': '아주대학교'}
# answer= 최병웅 {'SCIENCEON': 'Naval System R&D Center, Hanwha Systems', 'KCI': '한화시스템'}
# answer= 최요순 {'SCIENCEON': '부경대학교 환경해양대학 에너지자원공학과', 'KCI': '부경대학교'}
# answer= 최창현 {'SCIENCEON': 'Department of Bio-Mechatronic Engineering, Sungkyunkwan University', 'KCI': '성균관대학교'}
# answer= 한창수 {'NTIS': '한양대학교 에리카 산학협력단', 'SCIENCEON': '한양대학교 기계공학과'}
# answer= 허건수 {'NTIS': '한양대학교산학협력단', 'KCI': '한양대학교'}
# answer= 허기봉 {'SCIENCEON': 'Agency for Defense Development', 'KCI': '국방과학연구소(대전)'}
# answer= 황성호 {'NTIS': '성균관대학교산학협력단', 'SCIENCEON': 'Department of Mechanical Engineering, Sungkyunkwan University', 'KCI': '성균관대학교'}
# 토탈앤써 212
# 토탈인터그레이션 49
# --------------------------------
# 토탈에러 35
# 토탈인터그레이션에러 35
# 663

# %%
a = jaro.jaro_winkler_metric('성균관대학교', '성균관대학교(자연과학캠퍼스)')
print(a)
# Out:
# 0.88
